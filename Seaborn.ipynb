# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing1.csv")

# %%
print(df)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880             129
# 1    -122.22     37.86                  21         7099            1106
# 2    -122.24     37.85                  52         1467             190
# 3    -122.25     37.85                  52         1274             235
# 4    -122.25     37.85                  52         1627             280
# 5    -122.25     37.85                  52          919             213
# 6    -122.25     37.84                  52         2535             489
# 7    -122.25     37.84                  52         3104             687
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# ...

# %%
sns.countplot(x="housing_median_age",data=df)
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='count'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing1.csv")
plt.figure(figsize=(15,5))
sns.countplot(x="total_rooms",data=df,hue=('ocean_proximity'),palette="gist_gray")
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='count'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing1.csv")
plt.figure(figsize=(15,5))
sns.countplot(x="total_rooms",data=df)
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='count'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
df=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing1.csv")
plt.figure(figsize=(15,5))
sns.countplot(x="total_rooms",data=df,hue=('ocean_proximity'),palette="PuBuGn_r")
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='count'>

# %%
sns.countplot(x="total_rooms",data=df,facecolor=(1,0,0,0),linewidth=5,
             edgecolor=sns.color_palette('dark',3))
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='count'>

# %%
sns.barplot(x="total_rooms",y="housing_median_age",data=df)
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv(r"C:\\Users\\satish\\Documents\\Downloads\\Asosmenfashion.csv ")
df.head(7)
# Out:
#    product_id          brand_name  \
# 0   204499665              Replay
# 1   203420859        Jack & Jones
# 2   204285229        Jack & Jones
# 3   202261918   Don't Think Twice
# 4   202191610   Another Influence
# 5   201835675           Soul Star
# 6   203885388  Truffle Collection
#
#                                                title  current_price  \
# 0                            Replay t-shirt in white           72.0
# 1          Jack & Jones script logo t-shirt in white           17.0
# 2               Jack & Jones logo polo in pale green           34.0
# 3               DTT denim board shorts in light blue           31.0
# 4  Another Influence towelling shorts co-ord in m...           23.0
# 5        Soul Star dirty wash jersey shorts in black           23.0
# 6  Truffle Collection wide fit minimal chunky tra...           38.0
#
#    previous_price  colour currency    rrp  productCode productType
# 0             NaN     NaN      USD  100.0    127434315     Product
# ...

# %%
sns.boxplot('current_price',data=df)
# Out:
# C:\Users\satish\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='current_price'>

# %%
sns.boxplot(x='current_price',y='brand_name',data=df)
# Out:
# <AxesSubplot:xlabel='current_price', ylabel='brand_name'>

# %%
sns.violinplot(y='current_price',data=df)
# Out:
# <AxesSubplot:ylabel='current_price'>

# %%
df=pd.read_csv(r"C:\\Users\\satish\\Documents\\Downloads\\Asosmenfashion.csv ")
df1=df.head()
sns.violinplot(x='brand_name',y='current_price',data=df1)
# Out:
# <AxesSubplot:xlabel='brand_name', ylabel='current_price'>

# %%
sns.stripplot(y='rrp',data=df)
# Out:
# <AxesSubplot:ylabel='rrp'>

# %%
sns.stripplot(y='rrp',jitter=0.02,data=df)
# Out:
# <AxesSubplot:ylabel='rrp'>

# %%
df1=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing.csv")
df2=df1.head(500)
sns.swarmplot(y='total_rooms',data=df2)
# Out:
# <AxesSubplot:ylabel='total_rooms'>

# %%
sns.catplot(y='total_rooms',data=df2)# Default it print stripplot

# %%
sns.catplot(y="total_rooms",data=df2,kind='box')

# %%
sns.catplot(y="total_rooms",data=df2,kind='bar')

# %%
sns.catplot(y="total_rooms",data=df2,kind='swarm')

# %%
sns.histplot(data=df2,x='total_rooms')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='Count'>

# %%
sns.kdeplot(data=df2,x='total_rooms')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='Density'>

# %%
plt.figure(figsize=(15,10))
sns.rugplot(data=df2,x='total_rooms')
# Out:
# <AxesSubplot:xlabel='total_rooms'>

# %%
sns.ecdfplot(data=df2,x='total_rooms')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='Proportion'>

# %%
sns.scatterplot(data=df2,x='total_rooms',y='housing_median_age')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>

# %%
df1=pd.read_csv(r"C:\Users\satish\Documents\Downloads\housing.csv")
df2=df1.head(20)
sns.lineplot(data=df2,x='total_rooms',y='housing_median_age')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>

# %%
sns.relplot(data=df2,x='total_rooms',y='housing_median_age',kind='line')

# %%
sns.relplot(data=df2,x='total_rooms',y='housing_median_age',kind='scatter')

# %%
sns.regplot(data=df2,x='total_rooms',y='housing_median_age')
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='housing_median_age'>
